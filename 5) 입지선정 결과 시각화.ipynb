# %%
import folium
from folium.features import DivIcon

col_hex = ['#440154','#481a6c','#472f7d','#414487','#39568c','#31688e','#2a788e','#23888e','#1f988b','#22a884','#35b779','#54c568',
 '#7ad151','#a5db36','#d2e21b']
num=0

def number_DivIcon(color,number):
    """ Create a 'numbered' icon
    
    """
    icon = DivIcon(
            icon_size=(150,36),
            icon_anchor=(14,40),
#             html='<div style="font-size: 18pt; align:center, color : black">' + '{:02d}'.format(num+1) + '</div>',
            html="""<span class="fa-stack " style="font-size: 12pt" >>
                    <!-- The icon that will wrap the number -->
                    <span class="fa fa-circle-o fa-stack-2x" style="color : {:s}"></span>
                    <!-- a strong element with the custom content, in this case a number -->
                    <strong class="fa-stack-1x">
                         {:02d}  
                    </strong>
                </span>""".format(color,number)
        )
    return icon

# %%
import pandas as pd

df1 = pd.read_csv('df1.csv')
df2 = pd.read_csv('df2.csv')
df3 = pd.read_csv('df3.csv')
df4 = pd.read_csv('df4.csv')
df5 = pd.read_csv('df5.csv')
df6 = pd.read_csv('df6.csv')

# %%
m6 = folium.Map(location=(37.570962, 126.977881),zoom_start=15, tiles="Stamen Terrain")

import os 

for i in range(len(df6)) :
        lat = df6["latitude"][i]
        lon = df6["longitude"][i]
        name = df6["name"][i]
        loc = (lon, lat)
        #print(loc)
        folium.Marker(
              location=loc,
              popup=name,
              icon=folium.Icon(color='white',icon_color='white'),
              markerColor=col_hex[num],
            ).add_to(m6)
        folium.Marker(
              location=loc,
              popup=name,
              icon= number_DivIcon(col_hex[num],i+1)
            ).add_to(m6)
m6.save(os.path.join('map_test6.html')) # 저장하기
m6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m5 = folium.Map(location=(37.553838, 126.918765),zoom_start=15, tiles="Stamen Terrain")

for i in range(len(df5)) :
        lat = df5["latitude"][i]
        lon = df5["longitude"][i]
        name = df5["name"][i]
        loc = (lat, lon)
        folium.Marker(
              location=loc,
              popup=name,
              icon=folium.Icon(color='white',icon_color='white'),
              markerColor=col_hex[num],
            ).add_to(m5)
        folium.Marker(
              location=loc,
              popup=name,
              icon= number_DivIcon(col_hex[num],i+1)
            ).add_to(m5)
m5.save(os.path.join('map_test5.html')) # 저장하기
m5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m4 = folium.Map(location=(37.517598, 126.934571),zoom_start=15, tiles="Stamen Terrain")

for i in range(len(df4)) :
        lat = df4["latitude"][i]
        lon = df4["longitude"][i]
        name = df4["name"][i]
        loc = (lat, lon)
        #print(loc)
        folium.Marker(
              location=loc,
              popup=name,
              icon=folium.Icon(color='white',icon_color='white'),
              markerColor=col_hex[num],
            ).add_to(m4)
        folium.Marker(
              location=loc,
              popup=name,
              icon= number_DivIcon(col_hex[num],i+1)
            ).add_to(m4)
m4.save(os.path.join('map_test4.html')) # 저장하기
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m3 = folium.Map(location=(37.483594, 127.012518),zoom_start=15, tiles="Stamen Terrain") 

for i in range(len(df3)) :
        lat = df3["latitude"][i]
        lon = df3["longitude"][i]
        name = df3["name"][i]
        loc = (lat, lon)
        #print(loc)
        folium.Marker(
              location=loc,
              popup=name,
              icon=folium.Icon(color='white',icon_color='white'),
              markerColor=col_hex[num],
            ).add_to(m3)
        folium.Marker(
              location=loc,
              popup=name,
              icon= number_DivIcon(col_hex[num],i+1)
            ).add_to(m3)
m3.save(os.path.join('map_test3.html')) # 저장하기
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m2 = folium.Map(location=(37.477598, 126.888291),zoom_start=15, tiles="Stamen Terrain") 

for i in range(len(df2)) :
        lat = df2["latitude"][i]
        lon = df2["longitude"][i]
        name = df2["name"][i]
        loc = (lat, lon)
        #print(loc)
        folium.Marker(
              location=loc,
              popup=name,
              icon=folium.Icon(color='white',icon_color='white'),
              markerColor=col_hex[num],
            ).add_to(m2)
        folium.Marker(
              location=loc,
              popup=name,
              icon= number_DivIcon(col_hex[num],i+1)
            ).add_to(m2)
m2.save(os.path.join('map_test2.html')) # 저장하기
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m1 = folium.Map(location=(37.495361, 127.033058),zoom_start=15, tiles="Stamen Terrain")

for i in range(len(df1)) :
        lat = df1["latitude"][i]
        lon = df1["longitude"][i]
        name = df1["name"][i]
        loc = (lat, lon)
        #print(loc)
        folium.Marker(
              location=loc,
              popup=name,
              icon=folium.Icon(color='white',icon_color='white'),
              markerColor=col_hex[num],
            ).add_to(m1)
        folium.Marker(
              location=loc,
              popup=name,
              icon= number_DivIcon(col_hex[num],i+1)
            ).add_to(m1)
m1.save(os.path.join('map_test1.html')) # 저장하기
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
